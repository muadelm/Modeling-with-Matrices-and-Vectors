# %% [markdown]
# # Probabilistic modelling of Weather
#
# Reference:
#
# https://www.youtube.com/watch?v=K-8F_zDMDUI

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
A = np.array([[.5,.5,.25],[.25,0,.25],[.25,.5,.5]])

# %%
# the weather state todday in a column vector formate 
xtoday = np.array([[1],[0],[0]])

# %%
# Weather probability tomorrow is the multiplication of weather probability today by the probabilities in matrix A
tomorrow = (A@xtoday)
print(tomorrow)
# Out:
# [[0.5 ]
#  [0.25]
#  [0.25]]

# %%
# create a loop to find the weather in the coming 50 days 
for k in range(50):
    # initiate xtoday, the weather today is known 
    xtoday = np.array([[0],[1],[0]])

    xtomorrow = A@xtoday
    print(k)
    print(xtomorrow)
    print('    ')
    xtoday = xtomorrow
# Out:
# 0
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 1
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 2
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 3
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 4
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 5
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 6
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 7
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 8
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 9
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 10
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 11
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 12
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 13
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 14
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 15
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 16
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 17
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 18
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 19
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 20
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 21
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 22
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 23
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 24
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 25
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 26
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 27
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 28
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 29
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 30
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 31
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 32
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 33
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 34
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 35
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 36
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 37
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 38
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 39
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 40
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 41
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 42
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 43
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 44
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 45
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 46
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 47
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 48
# [[0.5]
#  [0. ]
#  [0.5]]
#
# 49
# [[0.5]
#  [0. ]
#  [0.5]]

# %%
# lets now collect the outcome in an array 

theweather = np.zeros((3,50))
theweather[:,0] = xtoday[:,0]
for k in range(50):
    # initiate xtoday, the weather today is known 
    xtoday = np.array([[1],[0],[0]])
    xtomorrow = A@xtoday

    theweather[:,k] = xtomorrow[:,0]

    xtoday = xtomorrow

# %%
plt.plot(theweather.transpose())
# Out:
# [<matplotlib.lines.Line2D at 0x1e771a605b0>,
#  <matplotlib.lines.Line2D at 0x1e771a60700>,
#  <matplotlib.lines.Line2D at 0x1e771b32f10>]
